# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
sns.set(style="whitegrid", font_scale=1.1)
df = pd.read_csv(
    "emissions.csv",
    sep=";",                # разделитель — точка с запятой
    decimal=",",            # десятичный разделитель — запятая
    encoding="utf-8-sig"    # безопасно для русских заголовков
)

# Проверяем результат
print(df.shape)
df.head()
# Out:
# (16000, 22)
#    P о.пар за кпп п1 т.2  F о.пар за КПП п2  F о.пар за КПП п1  \
# 0                    237                841                833
# 1                    237                841                832
# 2                    236                841                832
# 3                    237                841                831
# 4                    237                838                827
#
#   УП лопасти ДВ-Б УП лопасти ДС-Б    PM УП лопасти ДВ-А  \
# 0            63,1            54,7  60,2              63
# 1            63,1            54,7  60,1              63
# 2            63,1            54,7  60,1              63
# 3            63,1            54,7  60,1              63
# 4            62,8            54,7  60,1            62,7
#
#    Нормализованный расход  масс.конц-ция CO Влажная  масс.конц-ция NO Влажная  \
# 0                     261                         4                         7
# 1                     264                         4                         7
# 2                     265                         4                         7
# 3                     263                         4                         7
# 4                     229                         4                         6
#
#    масс.конц-ция O2 Влажная  масс.конц-ция SO2 Влажная  \
# 0                    113125                        383
# 1                    112747                        382
# 2                    113074                        382
# 3                    113097                        383
# 4                     97143                        330
#
#    масс. конц-ция пыли  [мг/м3]  масс. конц-ция пыли  [мг/м3].1  \
# 0                           636                             636
# 1                           183                             183
# 2                           807                             807
# 3                           179                             179
# 4                           259                             259
#
#    Текущий массовый расход CO  Текущий массовый расход NO  \
# 0                           1                           2
# 1                           1                           2
# 2                           1                           2
# 3                           1                           2
# 4                           1                           2
#
#    Текущий массовый расход O2  Текущий массовый расход SO2  \
# 0                       29526                          100
# 1                       29756                          101
# 2                       29952                          101
# 3                       29815                          101
# 4                       22244                           76
#
#    Текущий массовый расход пыли  масс. конц-ция пыли  NОx Влажная  \
# 0                           163                                 7
# 1                            48                                 7
# 2                           213                                 7
# 3                            47                                 7
# 4                            65                                 6
#
#    F возд до ДВ Б 1  F возд до ДВ А 1
# 0               957              1064
# 1               690               950
# 2               694              1039
# 3               855               992
# 4               813              1012
